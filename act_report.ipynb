# %% [markdown]
# ## Report: act_report
# * Create a **250-word-minimum written report** called "act_report.pdf" or "act_report.html" that communicates the insights and displays the visualization(s) produced from your wrangled data. This is to be framed as an external document, like a blog post or magazine article, for example.

# %% [markdown]
# The cleaned dataset provided insights or answers to the following questions using pandas horizontal barcharts
# Insights:
# 1.	What dog stage is associated with the highest likes?
# It was observed that the doggopuppo dog stage was associated with the highest likes with over 40k likes  followed by the puppo with over 20k likes a whopping difference of 20 thousand likes and then the doggo dog stage with almost 19k likes. Hence, dog owners that are more likely to have more likes fall to these categories

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 2.	What dog stage is associated with the highest popularity(retweet_counts)
# It was also observed that the progression was the same for the retweet counts, the doggopuppo had the highest with over 16k retweets followed by the doggo with 6k a retweet difference of over 10 thousand retweets. The puppo dog stage came in third with over 5k retweets.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 3.	Which dog breed(p1) has the highest likes and retweets
# To clear the air the analysis included the range of dog breeds that accrued the highest likes and retweets.
# The Saluki breed had the highest likes with over20k likes, followed by the French bulldog with over 16k likes
# While the standard poodle has the highest retweet with over 5k retweets followed by the English springer with close to 5k retweets while the saluki came 5th with just a little above 4k retweets

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Finally using seaborn heatmap, it was observed that a strong correlation existed between the ratings numerator and ratings denominator and at the same time a strong correlation existed between the favorite and retweet counts.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# In conclusion the dataset suggests that dogs in the doggopuppo stage of development are more likely to be popular and loved by people compared to dog in other dog stages.
